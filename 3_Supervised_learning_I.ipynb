# %%
import mglearn
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# a simulated binary classification dataset: forge
# forge has two features
# generate the dataset
X,y = mglearn.datasets.make_forge()
mglearn.discrete_scatter(X[:,0],X[:,1],y)
plt.legend(["Class 0","Class 1"],loc=4)
plt.xlabel("First feature")
plt.ylabel("Second feature")
print("X.shape: {}".format(X.shape))
# Out:
# X.shape: (26, 2)

# %%
X,y = mglearn.datasets.make_wave(n_samples=40)
plt.plot(X,y,'o')
plt.ylim(-3,3)
plt.xlabel("Feature")
plt.ylabel("Target")
# Out:
# Text(0, 0.5, 'Target')

# %%
# 生成wave数据集
X, y = mglearn.datasets.make_wave(n_samples=40)

# 绘制wave数据集的散点图
plt.scatter(X, y, c='r', s=100, edgecolor='k')
plt.xlabel("Feature")
plt.ylabel("Target")

# 打印数据集的形状
print("X.shape: {}".format(X.shape))

# 显示散点图
plt.show()
# Out:
# X.shape: (40, 1)

# %%
# Now we move to K-NN model
from sklearn.model_selection import train_test_split
X,y = mglearn.datasets.make_forge()

X_train, y_train, X_test, y_test = train_test_split(X, y, random_state = 0)

# %%
from sklearn.neighbors import KNeighborsClassifier
clf = KNeighborsClassifier(n_neighbors = 3)

# %%
clf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 clf.fit(X_train, y_train)
#
# File D:\Anaconda\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File D:\Anaconda\Lib\site-packages\sklearn\neighbors\_classification.py:228, in KNeighborsClassifier.fit(self, X, y)
#     206 @_fit_context(
#     207     # KNeighborsClassifier.metric is not validated yet
#     208     prefer_skip_nested_validation=False
#     209 )
#     210 def fit(self, X, y):
#     211     """Fit the k-nearest neighbors classifier from the training dataset.
#     212
#     213     Parameters
#    (...)
#     226         The fitted k-nearest neighbors classifier.
#     227     """
# --> 228     return self._fit(X, y)
#
# File D:\Anaconda\Lib\site-packages\sklearn\neighbors\_base.py:456, in NeighborsBase._fit(self, X, y)
#     454 if self._get_tags()["requires_y"]:
#     455     if not isinstance(X, (KDTree, BallTree, NeighborsBase)):
# --> 456         X, y = self._validate_data(
#     457             X, y, accept_sparse="csr", multi_output=True, order="C"
#     458         )
#     460     if is_classifier(self):
#     461         # Classification targets require a specific format
#     462         if y.ndim == 1 or y.ndim == 2 and y.shape[1] == 1:
#
# File D:\Anaconda\Lib\site-packages\sklearn\base.py:621, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     619         y = check_array(y, input_name="y", **check_y_params)
#     620     else:
# --> 621         X, y = check_X_y(X, y, **check_params)
#     622     out = X, y
#     624 if not no_val_X and check_params.get("ensure_2d", True):
#
# File D:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:1165, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1147 X = check_array(
#    1148     X,
#    1149     accept_sparse=accept_sparse,
#    (...)
#    1160     input_name="X",
#    1161 )
#    1163 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
# -> 1165 check_consistent_length(X, y)
#    1167 return X, y
#
# File D:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:409, in check_consistent_length(*arrays)
#     407 uniques = np.unique(lengths)
#     408 if len(uniques) > 1:
# --> 409     raise ValueError(
#     410         "Found input variables with inconsistent numbers of samples: %r"
#     411         % [int(l) for l in lengths]
#     412     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [19, 7]

# %%
print("Test set predictions: {}".format(clf.predict(X_test)))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print("Test set predictions: {}".format(clf.predict(X_test)))
#
# File D:\Anaconda\Lib\site-packages\sklearn\neighbors\_classification.py:244, in KNeighborsClassifier.predict(self, X)
#     230 def predict(self, X):
#     231     """Predict the class labels for the provided data.
#     232
#     233     Parameters
#    (...)
#     242         Class labels for each data sample.
#     243     """
# --> 244     check_is_fitted(self, "_fit_method")
#     245     if self.weights == "uniform":
#     246         if self._fit_method == "brute" and ArgKminClassMode.is_usable_for(
#     247             X, self._fit_X, self.metric
#     248         ):
#
# File D:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:1462, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1459     raise TypeError("%s is not an estimator instance." % (estimator))
#    1461 if not _is_fitted(estimator, attributes, all_or_any):
# -> 1462     raise NotFittedError(msg % {"name": type(estimator).__name__})
#
# NotFittedError: This KNeighborsClassifier instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.
